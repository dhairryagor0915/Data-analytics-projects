# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline 
import seaborn as sns

# %%
df1=pd.read_csv(r"C:\Users\dhair\OneDrive\Attachments\Desktop\tip.csv")

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df1.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df1.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df1.duplicated().sum()
# Out:
# 1

# %%
df1.drop_duplicates()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %%
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df1.sex.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
print(df1.sex.unique())
print(df1.time.unique())
print(df1.smoker.unique())
print(df1.day.unique())
# Out:
# ['Female' 'Male']
# ['Dinner' 'Lunch']
# ['No' 'Yes']
# ['Sun' 'Sat' 'Thur' 'Fri']

# %% [markdown]
# # Data Visualisation

# %%
#smoker.value_counts()
plt.figure(figsize=(4,4))
sns.countplot(x='smoker',data=df1,hue='sex',palette='Set1')
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='day',data=df1,palette='Set3')
plt.show()
# Out:
# C:\Users\dhair\AppData\Local\Temp\ipykernel_6744\3773325491.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='day',data=df1,palette='Set3')

# %%
x=df1['total_bill']
y=df1['tip']
plt.scatter(x,y)
plt.xlabel('total bill',fontsize =10)
plt.ylabel('tip',fontsize=10)
plt.show()

# %%
plt.hist(df1['tip'])
plt.show()

# %%
df1.day.value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,4))
sns.boxplot(df1['total_bill'],palette='rainbow')
plt.show()
# Out:
# C:\Users\dhair\AppData\Local\Temp\ipykernel_6744\2657746337.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(df1['total_bill'],palette='rainbow')

# %%
plt.figure(figsize=(10,6))
sns.stripplot(y='tip',x='time',hue='day',data=df1)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(y='total_bill',x='day',data=df1)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.pairplot(df1)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.distplot(df1['total_bill'],kde=True)
plt.show()
# Out:
# C:\Users\dhair\AppData\Local\Temp\ipykernel_6744\4208369384.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['total_bill'],kde=True)

# %%
plt.figure(figsize=(12,8))
sns.pairplot(data=df1,hue='sex')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='day',y='total_bill',data=df1)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.violinplot(x='day',y='total_bill',data=df1,hue='smoker',split=True)
plt.show()

# %%
a=df1.groupby('sex').agg({'total_bill':'mean'})
print(a)
# Out:
#         total_bill
# sex
# Female   18.056897
# Male     20.744076

# %%
plt.figure(figsize=(15,15))
df1.groupby('day').agg({'total_bill':'mean'})
df1.plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.jointplot(data=df1,x='total_bill',y='tip',kind='reg')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.swarmplot(x='day',y='total_bill',data=df1)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.swarmplot(x='size',y='total_bill',data=df1)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.catplot(x='smoker',y='tip',order=['No','Yes'],data=df1);
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='day',y='total_bill',hue='smoker',data=df1);
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.violinplot(x='day',y='total_bill',inner=None,data=df1)
sns.swarmplot(x='day',y='total_bill',color='k',size=3,data=df1)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='day',hue='size',data=df1)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.pointplot(x='day',y='tip',data=df1)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.pointplot(x='day',y='size',hue='sex',linestyles=["-","--"],data=df1)
plt.show()
